# %%
import pandas as pd

# %%
path = "/home/sebastian/Desktop/Python/Data_aggregation/cl-pipeline/run/data/raw/OPAL_files_attrib.p"

df = pd.read_pickle(path)

# %%
df.publisher.unique()
# Out:
# array(['SLUB Dresden', '', 'metadata', 'ESRI', 'Prof. Dr. Nadine Bergner',
#        'IMB, MF, TU Dresden, Germany', 'Technische Universität Dresden',
#        'Landesbetrieb Geobasisinformation und Vermessung - Freistaat Sachsen',
#        'b',
#        'Schülerlabor Informatik - InfoSphere, Informatik entdecken in Modulen für alle Schulformen & Klassenstufen',
#        'TH Bochum', 'Schreibzentrum der TU Dresden', 'Denis Keiling',
#        'Herausgeber', 'Tenshi Hara', 'Technische Universität Dresdden',
#        'IMB, MF, TU Dresden', 'Institut Berufspädagogik',
#        'Institute of Metallurgy and Materials Science of Polish Academy of Sciences, Commitee on Metallurgy of Polish Academy of Sciences',
#        'tuuwi, SLUB Dresden', 'tuuwi (TU-Umweltinitiative)', 'tuuwi',
#        'TU-Umweltinitiative (tuuwi)', 'Bildungstechnologie',
#        'Patricia Kaden', 'Guido Philipp', 'Prof. Dr. Tina Geweniger',
#        'Prof. Dr. Frank Grimm', 'Publishers Association',
# ...

# %%
# rename pandas column
df = df.rename(columns={'creator': 'creators', 'old_name2': 'new_name2'})
# Out:
#                                           filename               license  \
# 0                                  SC_Hardware.png        CC BY 4.0 Int.
# 1                                        beleg.pdf     CC BY-SA 4.0 Int.
# 2                                  Bereich III.pdf  CC BY-NC-ND 4.0 Int.
# 3                                   uebung6_A2d.py    CC0 1.0 Universell
# 4                         ITM_Selbststudium_1.docx  CC BY-NC-SA 4.0 Int.
# ...                                            ...                   ...
# 13708              PPT_Beurskens_Prüfungsrecht.pdf     CC BY-ND 4.0 Int.
# 13709  Basic principles of statistical algebra.pdf     CC BY-SA 4.0 Int.
# 13710        2tA_SLS-technVerfahren_2024-05-27.pdf  CC BY-NC-SA 4.0 Int.
# 13711                           Ma2BIB_Vorl_08.pdf  CC BY-NC-ND 4.0 Int.
# 13712                    Antworten Web-Rallye.docx     CC BY-SA 4.0 Int.
#
#                                            oer_permalink  \
# ...
