# %% [markdown]
# # Mehrstufige Extraktion von Metadateninformationen aus sächsischen OER Inhalten
#
# Sebastian Zug, André Dietrich
# TU Bergakademie Freiberg, Institut für Informatik

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 1. Schritt: Bewertung der Metadaten von OER Inhalten aus dem LMS OPAL

# %%
data_folder =  "/mnt/9cd5c6a1-07f3-4580-be34-8d8dd9d6fe6d/Connected_Lecturers/Opal/raw/"
data_file_attribs = "OPAL_files_attrib.p"
data_file_meta = "OPAL_files_meta.p"

# %%
df_files = pd.read_pickle(Path(data_folder) / data_file_attribs)

# %%
def generateEmptinessStatistics(df):
    df_empty = df.apply(lambda x: x == '').sum(axis=0).rename("count").to_frame()
    df_empty['empty_in_percent'] = df_empty / len(df)
    return df_empty

# %%
generateEmptinessStatistics(df_files)
# Out:
#                        count  empty_in_percent
# opal:filename              0          0.000000
# opal:oer_permalink         0          0.000000
# opal:license               0          0.000000
# opal:creator           13737          0.978419
# opal:title             13695          0.975427
# opal:comment           13848          0.986325
# opal:language          14007          0.997650
# opal:publicationMonth  13826          0.984758
# opal:publicationYear   13826          0.984758
# pipe:ID                    0          0.000000
# pipe:file_type             0          0.000000

# %% [markdown]
# Ok, wer sind die metainformationsspezifischen Vorbilder?

# %%
df_files[df_files["opal:creator"]!=""]['opal:creator'].value_counts().head(10)
# Out:
# opal:creator
# Frank Babick                           91
# Prof. Dr.-Ing. Johann Zitzelsberger    29
# Dominik Kern                           20
# Monique Meier                          10
# Daniela Dobeleit                        7
# Benno Wessely; Frank Babick             5
# Valerie Uhlig                           5
# Guido Philipp                           4
# Nielsen Book Data                       4
# Hartmut Simmert                         3
# Name: count, dtype: int64

# %% [markdown]
# ## Schritt 2: Traditionelle Aggregation der Metadaten
#
# Welche Dateitypen sind denn  in den OPAL OER Daten überhaupt vertreten?

# %%
df_files["pipe:file_type"].value_counts().head(10)
# Out:
# pipe:file_type
# pdf     6992
# jpg     1237
# mkv      869
# mp4      602
# png      563
# zip      466
# docx     441
# html     430
# pptx     224
# xlsx     208
# Name: count, dtype: int64

# %% [markdown]
# Im Rahmen der ersten Untersuchungsreihe fokussieren wir uns auf {`pdf`, `docx`, `pptx`, `xlsx`}. Ausgangspunkt war eine Stichprobenprüfung der Mediendateien, die keinerlei Metadaten enthielten.

# %%
relevant_file_type = ['pdf', 'docx', 'pptx', 'xlsx']
df_files[df_files["pipe:file_type"].isin(relevant_file_type)]["pipe:file_type"].shape[0] / df_files.shape[0]
# Out:
# 0.5601851851851852

# %% [markdown]
# Schauen wir uns die Resultate an.

# %%
df_meta = pd.read_pickle(Path(data_folder) / data_file_meta)

# %%
df_meta.shape
# Out:
# (7865, 9)

# %%
generateEmptinessStatistics(df_meta)
# Out:
#                 count  empty_in_percent
# pipe:ID             0          0.000000
# pipe:file_type      0          0.000000
# file:author      2856          0.363128
# file:keywords    6930          0.881119
# file:subject     6564          0.834584
# file:title       3503          0.445391
# file:created        0          0.000000
# file:modified       0          0.000000
# file:language     654          0.083153

# %% [markdown]
# Für 40 Prozent der Autoren können wir zumindest einen Vorschlage zum Namen machen? Das klingt schon mal vielversprechend. Lassen Sie uns die Metadaten der verschiedenen Quellen vergleichen, um die Qualitäten zu prüfen.

# %%
# merge df_files and df_meta on "opal:file_id"
df_merge = pd.merge(df_meta, df_files, on="pipe:ID", how="left")

# %% [markdown]
# Schauen wir uns zunächst positiv Beispiel an, die aus beiden Quellen enthielten.

# %%
df_merge[(df_merge["opal:creator"]!="") &  (df_merge["file:author"]!="")][["opal:creator", "file:author"]].head(15)
# Out:
#                                  opal:creator  \
# 300                                      ESRI
# 308                  Prof. Dr. Nadine Bergner
# 360                   Jost-Hinrich Eschenburg
# 379                     Roeder, Klimova, Kuhn
# 400                              Frank Babick
# 423                              Frank Babick
# 424                              Frank Babick
# 443                              Frank Babick
# 486              Sophia Peukert; Frank Irmler
# 527                               Oliver Löwe
# 635    Ahnert, Carolin ; Jackenkroll, Martina
# 754       Prof. Dr.-Ing. Johann Zitzelsberger
# 759               Frank Richter, Tom C. Adler
# 931  Frank Babick, LE Hoai Nga, PHAN Duy Dung
# 976                              Frank Babick
#
#                                            file:author
# 300                                               ESRI
# 308                           Prof. Dr. Nadine Bergner
# 360                           Jost-Hinrich Eschenburg
# 379  Institute of Medical Informatics and Biometry ...
# 400                                  Frank Babick u.a.
# 423                                       Frank Babick
# 424                                       Frank Babick
# 443                                       Frank Babick
# 486                                           ms733714
# 527                                        Löwe Oliver
# 635                                Martina Jackenkroll
# 754                Prof. Dr.-Ing. Johann Zitzelsberger
# 759                             Adler, Tom Christopher
# 931                                       Frank Babick
# 976                                       Frank Babick

# %% [markdown]
# Und nun umgekehrt, helfen uns die aus den Dateien extrahierten Metadaten bei der Identifikation der Autoren? Das Bild ist durchwachsen ... offenbar brauchen wir hier noch einen Testmechanismus, der überprüft, ob sich hinter den Angaben eine Person _aus dem akademischen Umfeld_ verbirgt.

# %%
df_merge[(df_merge["opal:creator"]=="") &  (df_merge["file:author"]!="")][["opal:creator", "file:author"]].head(15)
# Out:
#    opal:creator                                        file:author
# 5                                                        Ralf Laue
# 6                                      Walter, Susanne (FIN A 2.3)
# 10                                                            home
# 11                                                            home
# 12                                                            home
# 21                                                            Anja
# 22                                                            Anna
# 23                                                 P. Menzel;Hamza
# 24                                                      lschlenker
# 25               Rana M. Tamim, Robert M. Bernard, Eugene Borok...
# 26                 Prof.Dr. Florian Sahling, name@subdomain.domain
# 32                                                   Yvonne Seidel
# 33                                                            home
# 34                                                            home
# 35                                                Christian Müller

# %% [markdown]
# ### Schritt 3: KI basierte Metadatenaggregation

# %%
data_file_aimeta = "OPAL_ai_meta.p"
df_aimeta = pd.read_pickle(Path(data_folder) / data_file_aimeta)

# %%
df_aimeta.shape
# Out:
# (439, 6)

# %%
df_aimeta.head(10)
# Out:
#         pipe:ID pipe:file_type  \
# 0  8I6sM5zapD60            pdf
# 0  8ZICOHBmAHyQ            pdf
# 0  3ztCv-WpxJ4U            pdf
# 0  6mOhjfscZK2A            pdf
# 0  1eteONeHL82Y            pdf
# 0  1mjbqKfwSW7U            pdf
# 0  1BruMQFjEIRY            pdf
# 0  1hZf0CFwsBhA            pdf
# 0  1PrtXFruGers            pdf
# 0  1LvS8_gxjyYc            pdf
#
#                                        ai:author_raw  \
# 0                      Stephan Gerhold, Marcel Beyer
# 0  I don't know. The context provided does not me...
# 0                                  Norbert Engemaier
# 0  I don't know. The provided context does not me...
# 0  I don't know. The provided context does not me...
# 0                                         TU Dresden
# 0  The author of the document "1BruMQFjEIRY.pdf" ...
# 0  I don't know. The context does not provide any...
# 0  I don't know. The context only provides inform...
# 0  I don't know. The context provided does not me...
#
#                                            ai:author  \
# 0                      Stephan Gerhold, Marcel Beyer
# 0
# 0                                  Norbert Engemaier
# 0
# 0
# 0                                         TU Dresden
# 0  The author of the document "1BruMQFjEIRY.pdf" ...
# 0
# 0
# 0
#
#                                             ai:title  \
# 0                          "Übung 3 Photogrammetrie"
# 0                           Grundlagen der Tragwerke
# 0                                            Referat
# 0  Vorlesung Technische Mechanik I - AGBF, TU Dre...
# 0         "Modellelemente auf 'beste Größe' bringen"
# 0                     "E-Learning an der TU Dresden"
# 0                             Erste Schritte in OPAL
# 0                            "Tafel 3: Wiederholung"
# 0  "Interfaces geben keine Struktur vor, sondern ...
# 0  "Zusammenfassung: IDisposable, IComparable und...
#
#                                          ai:keywords
# 0  Fensterabstand, Photogrammetrie, Passpunkte, E...
# 0  I'm happy to help! However, I need to clarify ...
# 0       Thesis, Essay, Referat, Prüfung, Zitierweise
# 0  I'm happy to help! However, I need to clarify ...
# 0  Konnektoren, Ereignisse, Syntaxregeln, Prozess...
# 0  I can help you with that! However, I need to c...
# 0  OPAL, Navigation, Startseite, Kursangebote, Fa...
# 0  I'd be happy to help! However, I need to clari...
# 0  Interfaces, Klassen, Generische Schnittstellen...
# 0  Ich kann leider keine Datei mit dem Namen "1Lv...

# %%
df_merge_all = pd.merge(df_aimeta, df_merge, on="pipe:ID", how="left")
df_merge_all
# Out:
#           pipe:ID pipe:file_type  \
# 0    8I6sM5zapD60            pdf
# 1    8ZICOHBmAHyQ            pdf
# 2    3ztCv-WpxJ4U            pdf
# 3    6mOhjfscZK2A            pdf
# 4    1eteONeHL82Y            pdf
# ..            ...            ...
# 434  4Sq2K1faySBw            pdf
# 435  6m4UxzhXYoDg            pdf
# 436  1pic31NO7y20            pdf
# 437  1tRioCE7tA_U            pdf
# 438  1SS1-wN5VtKA            pdf
#
#                                          ai:author_raw  \
# 0                        Stephan Gerhold, Marcel Beyer
# 1    I don't know. The context provided does not me...
# 2                                    Norbert Engemaier
# 3    I don't know. The provided context does not me...
# 4    I don't know. The provided context does not me...
# ..                                                 ...
# 434                                 Christoph Scheffel
# 435                              Dr.-Ing. Martin Kache
# 436  I don't know. The context provided does not me...
# 437                                       Lutz Hellmig
# 438  I don't know. The context does not provide any...
#
#                          ai:author  \
# 0    Stephan Gerhold, Marcel Beyer
# 1
# 2                Norbert Engemaier
# 3
# 4
# ..                             ...
# 434             Christoph Scheffel
# 435          Dr.-Ing. Martin Kache
# 436
# 437                   Lutz Hellmig
# 438
#
#                                               ai:title  \
# 0                            "Übung 3 Photogrammetrie"
# 1                             Grundlagen der Tragwerke
# 2                                              Referat
# 3    Vorlesung Technische Mechanik I - AGBF, TU Dre...
# 4           "Modellelemente auf 'beste Größe' bringen"
# ..                                                 ...
# 434  ES Experimentalpsychologisches Arbeiten 6. Abs...
# 435                 Fahrdynamik für Verkehrsingenieure
# 436  Keine Antwort, da keine Datei mit diesem Titel...
# 437  Grundlagen zur Didaktik der Informatik WS 2018...
# 438  Aufgaben zum Seminar 1: Informatikdidaktik und...
#
#                                            ai:keywords pipe:file_type_x  \
# 0    Fensterabstand, Photogrammetrie, Passpunkte, E...              pdf
# 1    I'm happy to help! However, I need to clarify ...              pdf
# 2         Thesis, Essay, Referat, Prüfung, Zitierweise              pdf
# 3    I'm happy to help! However, I need to clarify ...              pdf
# 4    Konnektoren, Ereignisse, Syntaxregeln, Prozess...              pdf
# ..                                                 ...              ...
# 434  I can help you with that! However, I need to c...              pdf
# 435  I can help you with that! However, I need to c...              pdf
# 436        Lesen, Schreiben, Suchen, Stream-Klasse, C#              pdf
# 437  Informatik, Didaktik, Berufswissenschaft, Bild...              pdf
# 438  I can help you with that!\n\nThe PDF file is n...              pdf
#
#                                            file:author file:keywords  \
# 0
# 1
# 2
# 3
# 4                                            Ralf Laue
# ..                                                 ...           ...
# 434                                        Diana Vogel
# 435  Dr.-Ing. Martin Kache, Professur für Technik s...   Fahrdynamik
# 436                                               home
# 437                                   Dr. Lutz Hellmig
# 438
#
#                                           file:subject  ...  \
# 0                                                       ...
# 1                                                       ...
# 2                                                       ...
# 3                                                       ...
# 4                                                       ...
# ..                                                 ...  ...
# 434                                                     ...
# 435  Fahrdynamik, Luftwiderstand, Fahrzeugwiderstan...  ...
# 436                                                     ...
# 437                                                     ...
# 438                                                     ...
#
#                                         opal:filename  \
# 0                                           beleg.pdf
# 1                                     Bereich III.pdf
# 2                000 Prüfungsleistungen Engemaier.pdf
# 3                                       Bereich I.pdf
# 4                     GPM-2018-01-Einfuehrung-EPK.pdf
# ..                                                ...
# 434                        ES_ExPra2_06_Abschluss.pdf
# 435             Folien_Fahrdynamik_VIW_2019_VL_03.pdf
# 436                                            17.pdf
# 437  01 Einführung in die Didaktik der Informatik.pdf
# 438             PS01 Informatik und ihre Didaktik.pdf
#
#                                     opal:oer_permalink          opal:license  \
# 0    https://bildungsportal.sachsen.de/opal/oer/8I6...     CC BY-SA 4.0 Int.
# 1    https://bildungsportal.sachsen.de/opal/oer/8ZI...  CC BY-NC-ND 4.0 Int.
# 2    https://bildungsportal.sachsen.de/opal/oer/3zt...     CC BY-SA 4.0 Int.
# 3    https://bildungsportal.sachsen.de/opal/oer/6mO...  CC BY-NC-ND 4.0 Int.
# 4    https://bildungsportal.sachsen.de/opal/oer/1et...     CC BY-NC 4.0 Int.
# ..                                                 ...                   ...
# 434  https://bildungsportal.sachsen.de/opal/oer/4Sq...        CC BY 4.0 Int.
# 435  https://bildungsportal.sachsen.de/opal/oer/6m4...  CC BY-NC-ND 4.0 Int.
# 436  https://bildungsportal.sachsen.de/opal/oer/1pi...        CC BY 4.0 Int.
# 437  https://bildungsportal.sachsen.de/opal/oer/1tR...  CC BY-NC-SA 4.0 Int.
# 438  https://bildungsportal.sachsen.de/opal/oer/1SS...  CC BY-NC-SA 4.0 Int.
#
#     opal:creator opal:title opal:comment opal:language opal:publicationMonth  \
# 0
# 1
# 2
# 3
# 4
# ..           ...        ...          ...           ...                   ...
# 434
# 435
# 436
# 437
# 438
#
#     opal:publicationYear pipe:file_type_y
# 0                                     pdf
# 1                                     pdf
# 2                                     pdf
# 3                                     pdf
# 4                                     pdf
# ..                   ...              ...
# 434                                   pdf
# 435                                   pdf
# 436                                   pdf
# 437                                   pdf
# 438                                   pdf
#
# [439 rows x 24 columns]

# %%
df_merge_all[ (df_merge_all["opal:creator"]!="") &
             ((df_merge_all["file:author"]!="") | (df_merge_all["ai:author"]!=""))][["opal:creator", "file:author", "ai:author"]].tail(20)
# Out:
#                      opal:creator  \
# 245                          ESRI
# 252      Prof. Dr. Nadine Bergner
# 296       Jost-Hinrich Eschenburg
# 311         Roeder, Klimova, Kuhn
# 331                  Frank Babick
# 353                  Frank Babick
# 354                  Frank Babick
# 371                  Frank Babick
# 403  Sophia Peukert; Frank Irmler
#
#                                            file:author  \
# 245                                               ESRI
# 252                           Prof. Dr. Nadine Bergner
# 296                           Jost-Hinrich Eschenburg
# 311  Institute of Medical Informatics and Biometry ...
# 331                                  Frank Babick u.a.
# 353                                       Frank Babick
# 354                                       Frank Babick
# 371                                       Frank Babick
# 403                                           ms733714
#
#                     ai:author
# 245
# 252  Prof. Dr. Nadine Bergner
# 296          J.-H. Eschenburg
# 311
# 331
# 353              Frank Babick
# 354              Frank Babick
# 371              Frank Babick
# 403              MANDY SCHÜTZ

# %%
df_merge_all[ (df_merge_all["opal:creator"]=="") &
             ((df_merge_all["file:author"]!="") | (df_merge_all["ai:author"]!=""))][["opal:creator", "file:author", "ai:author"]].tail(20)
# Out:
#     opal:creator                                        file:author  \
# 417                                                            home
# 418                                                            home
# 419
# 420                                                         banusch
# 421                                                           MWill
# 422                                                           MWill
# 423                                                           MWill
# 424                                                  Andreas Sommer
# 425
# 426                                                       alexander
# 427                                                     Diana Vogel
# 428                                                   Anke Hoffmann
# 429                                          Prof. Bernd Delakowitz
# 430                                                              TW
# 432                                                     Diana Vogel
# 433                                                          Ulrike
# 434                                                     Diana Vogel
# 435               Dr.-Ing. Martin Kache, Professur für Technik s...
# 436                                                            home
# 437                                                Dr. Lutz Hellmig
#
#                                              ai:author
# 417
# 418
# 419                                    Hamann/Meinhold
# 420                                  W. Domschke, u.a.
# 421  The author of the document is not specified in...
# 422
# 423                                   Bernd Delakowitz
# 424  Prof. Dr. Bernd Delakowitz / Dipl. Ing. Eric S...
# 425                                          M. Hamann
# 426                               Alexander Eychmüller
# 427
# 428                                   Bernd Delakowitz
# 429                                   Bernd Delakowitz
# 430
# 432
# 433                                         TU Dresden
# 434                                 Christoph Scheffel
# 435                              Dr.-Ing. Martin Kache
# 436
# 437                                       Lutz Hellmig
